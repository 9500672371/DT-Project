# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the Dataset

# %%
data = pd.read_csv('C:\\Users\\jha9001\\AppData\\Local\\Temp\\Temp1_avocado.csv (2).zip\\avocado.csv')

# %%
# Basic checks of the dataset

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.shape
# Out:
# (18249, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
data.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
data.rename(columns = {'4046':'Variety_1','4225':'Variety_2','4770':'Variety_3'}, inplace =True)

# %%
data['Date'].nunique()
# Out:
# 169

# %%
#since we are not doing Time series approach, dropping Date column

# %%
data = data.drop(columns = ['Unnamed: 0','Date'])

# %%
data.type.unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
data.region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
data.region.nunique()
# Out:
# 54

# %%
from sklearn.preprocessing import LabelEncoder
enco = LabelEncoder()

# %%
encoded_type = enco.fit_transform(data['type'])
encoded_type
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
data.type = encoded_type

# %%
encoded_region = enco.fit_transform(data['region'])
encoded_region
# Out:
# array([ 0,  0,  0, ..., 53, 53, 53])

# %%
data.region = encoded_region

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   Variety_1     18249 non-null  float64
#  3   Variety_2     18249 non-null  float64
#  4   Variety_3     18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  int32
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  int32
# dtypes: float64(9), int32(2), int64(1)
# memory usage: 1.5 MB

# %%
data.describe()
# Out:
#        AveragePrice  Total Volume     Variety_1     Variety_2     Variety_3  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          type  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507      0.499918
# ...

# %%
# Mean and Std numbers are seems fine

# %%
data
# Out:
#        AveragePrice  Total Volume  Variety_1  Variety_2  Variety_3  \
# 0              1.33      64236.62    1036.74   54454.85      48.16
# 1              1.35      54876.98     674.28   44638.81      58.33
# 2              0.93     118220.22     794.70  109149.67     130.50
# 3              1.08      78992.15    1132.00   71976.41      72.58
# 4              1.28      51039.60     941.48   43838.39      75.78
# ...             ...           ...        ...        ...        ...
# 18244          1.63      17074.83    2046.96    1529.20       0.00
# 18245          1.71      13888.04    1191.70    3431.50       0.00
# 18246          1.87      13766.76    1191.92    2452.79     727.94
# 18247          1.93      16205.22    1527.63    2981.04     727.01
# 18248          1.62      17489.58    2894.77    2356.13     224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# 0         8696.87     8603.62       93.25          0.0     0  2015       0
# ...

# %%
data.shape
# Out:
# (18249, 12)

# %%
plt.figure(figsize=(25,20),facecolor='lightblue')
plotnumber = 1


for column in data:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(data[column],color = 'green')
        plt.xlabel(column,fontsize=12)
        
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,22),facecolor='orange')
plotnumber = 1


for column in data:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.scatterplot(data[column],data['AveragePrice'])
        plt.xlabel(column,fontsize=12)
        
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,22),facecolor='lightpink')
plotnumber = 1


for column in data:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.boxplot(data[column],color = 'orange')
        plt.xlabel(column,fontsize=12)
        
    plotnumber+=1
plt.show()

# %%
#from the above plots, its clear that the data set have Skewness and outliers that needs to be treated

# %%
# Data Preprocessing

# %%
from scipy.stats import zscore
import numpy as np
z_score =zscore(data[['Total Volume', 'Variety_1', 'Variety_2', 'Variety_3',
       'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']])
scaled_z_score = np.abs(z_score)
filtering_entry =(scaled_z_score <1.5).all(axis=1)
data = data[filtering_entry]

# %%
data.shape
# Out:
# (16991, 12)

# %%
plt.figure(figsize=(25,20),facecolor='lightblue')
plotnumber = 1


for column in data:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(data[column],color = 'green')
        plt.xlabel(column,fontsize=12)
        
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,22),facecolor='lightpink')
plotnumber = 1


for column in data:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.boxplot(data[column],color = 'orange')
        plt.xlabel(column,fontsize=12)
        
    plotnumber+=1
plt.show()

# %%
df_corr = data.corr().abs()

plt.figure(figsize =(12, 10))
sns.heatmap(df_corr, annot = True, annot_kws={'size' :10})
plt.show()

# %%
#HEatmap analysis for Corelation
# Total Bags and total volumns has high corelation. In this, we have total volumne which has higher relation to price.
# so Total bags feature wll be dropped

# %%
#VIZUALIZE THE CORELATION

# %%
from sklearn.preprocessing import StandardScaler

# %%
data.drop('AveragePrice',axis =1).corrwith(data.AveragePrice).plot(kind = 'bar', grid=True, figsize = (15,7))
# Out:
# <AxesSubplot:>

# %%
x = data.drop(columns = ['AveragePrice','Total Bags'],axis =1)
y = data.AveragePrice

# %%
scale = StandardScaler()
x_scaled = scale.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['Features'] = x.columns
vif
# Out:
#             vif      Features
# 0  9.992838e+07  Total Volume
# 1  1.922843e+07     Variety_1
# 2  1.611261e+07     Variety_2
# 3  1.448158e+05     Variety_3
# 4  6.257697e+06    Small Bags
# 5  8.021208e+05    Large Bags
# 6  2.844116e+03   XLarge Bags
# 7  1.389817e+00          type
# 8  1.092675e+00          year
# 9  1.045248e+00        region

# %%
from scipy.stats import skew

# %%
for col in x:
    print(col)
    print(skew(x[col]))
    
    plt.figure()
    sns.distplot(x[col])
    plt.show()
# Out:
# Total Volume
# 3.506713744951152
# Variety_1
# 4.704982454877528
# Variety_2
# 4.134654485964284
# Variety_3
# 5.003976497476922
# Small Bags
# 4.392558222208912
# Large Bags
# 4.24914846840118
# XLarge Bags
# 5.880952597967165
# type
# -0.14741784661362917
# year
# 0.2189653813677311
# region
# 0.004382700735243876

# %%
data['Total Volume'] = np.log(data['Total Volume'])
skew(data['Total Volume'])
# Out:
# -0.13581879404935687

# %%
for col in data:
    print(col)
    print(skew(data[col]))
    
    plt.figure()
    sns.distplot(data[col])
    plt.show()
# Out:
# AveragePrice
# 0.5348099871390218
# Total Volume
# -0.13581879404935687
# Variety_1
# 4.704982454877528
# Variety_2
# 4.134654485964284
# Variety_3
# 5.003976497476922
# Total Bags
# 3.9999074810701125
# Small Bags
# 4.392558222208912
# Large Bags
# 4.24914846840118
# XLarge Bags
# 5.880952597967165
# type
# -0.14741784661362917
# year
# 0.2189653813677311
# region
# 0.004382700735243876

# %%
x = data.drop(columns = ['AveragePrice','Total Bags'],axis =1)
y = data.AveragePrice

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
#selction of Random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import  LinearRegression

# %%
lr = LinearRegression()

# %%
for i in range(0,101):
    x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,train_size = 0.75,random_state = i)
    lr.fit(x_train, y_train)
    predict_train = lr.predict(x_train)
    predict_test = lr.predict(x_test)
    print(f"At random state {i}, the train set accuracy is ",{r2_score(y_train,predict_train)})
    print(f"At random state {i}, the test set accuracy is ",{r2_score(y_test,predict_test)})
# Out:
# At random state 0, the train set accuracy is  {0.42544793890948307}
# At random state 0, the test set accuracy is  {0.4187196122890817}
# At random state 1, the train set accuracy is  {0.4238487593573771}
# At random state 1, the test set accuracy is  {0.42331485306156824}
# At random state 2, the train set accuracy is  {0.4280056414625769}
# At random state 2, the test set accuracy is  {0.41117160355107163}
# At random state 3, the train set accuracy is  {0.42396210526076994}
# At random state 3, the test set accuracy is  {0.42313035995864956}
# At random state 4, the train set accuracy is  {0.4258053936484393}
# At random state 4, the test set accuracy is  {0.4179651791490636}
# At random state 5, the train set accuracy is  {0.4186832729700193}
# At random state 5, the test set accuracy is  {0.4388438814395802}
# At random state 6, the train set accuracy is  {0.4254293744065165}
# At random state 6, the test set accuracy is  {0.4183085696399258}
# ...

# %%
# at random state 77, the model perfroms well.So random state is 77
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,train_size = 0.75,random_state = 77)
lr.fit(x_train, y_train)
predict_train = lr.predict(x_train)
predict_test = lr.predict(x_test)
print(f"The train set accuracy is ",{r2_score(y_train,predict_train)})
print(f"The test set accuracy is ",{r2_score(y_test,predict_test)})
# Out:
# The train set accuracy is  {0.42599951659523805}
# The test set accuracy is  {0.4172880698372816}

# %%
#Model

# %%
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    clf.fit(x_train, y_train)
    if train:
        train_pred = clf.predict(x_train)
        print("\n===================Train Results============")
        print('R2_score:', r2_score(y_train, train_pred)*100,'% \n')
        print('Mean Squared Error:', mean_squared_error(y_train, train_pred),'\n')
        print('Mean Absolute Error:', mean_absolute_error(y_train, train_pred),'\n')
        
    elif train == False:
        test_pred = clf.predict(x_test)
        print("\n===================Test Results============")
        print('R2_score:', r2_score(y_test, test_pred)*100,'%\n')
        print('Mean Squared Error:', mean_squared_error(y_test, test_pred),'\n')
        print('Mean Absolute Error:', mean_absolute_error(y_test, test_pred),'\n')

# %%
metric_score(lr,x_train,x_test,y_train,y_test,train=True)
metric_score(lr,x_train,x_test,y_train,y_test,train=False)
# Out:
# ===================Train Results============
# R2_score: 42.5999516595238 %
#
# Mean Squared Error: 0.09225609249096384
#
# Mean Absolute Error: 0.23367571112426008
#
#
# ===================Test Results============
# R2_score: 41.72880698372816 %
#
# Mean Squared Error: 0.09569372028942537
#
# Mean Absolute Error: 0.2347635087623083

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
rf = RandomForestRegressor()
dt = DecisionTreeRegressor()
knn = KNeighborsRegressor()
gbr = GradientBoostingRegressor()

# %%
#random Forest

# %%
metric_score(rf,x_train,x_test,y_train,y_test,train=True)
metric_score(rf,x_train,x_test,y_train,y_test,train=False)
# Out:
# ===================Train Results============
# R2_score: 97.68763433849901 %
#
# Mean Squared Error: 0.003716544262732482
#
# Mean Absolute Error: 0.04202288315153418
#
#
# ===================Test Results============
# R2_score: 84.528672323233 %
#
# Mean Squared Error: 0.025407217984934085
#
# Mean Absolute Error: 0.11145211864406779

# %%
#decision Tree

# %%
metric_score(dt,x_train,x_test,y_train,y_test,train=True)
metric_score(dt,x_train,x_test,y_train,y_test,train=False)
# Out:
# ===================Train Results============
# R2_score: 100.0 %
#
# Mean Squared Error: 1.3831994703784024e-34
#
# Mean Absolute Error: 7.405552624432105e-19
#
#
# ===================Test Results============
# R2_score: 69.08833951937318 %
#
# Mean Squared Error: 0.05076353578154425
#
# Mean Absolute Error: 0.14920197740112992

# %%
# KNN

# %%
metric_score(knn,x_train,x_test,y_train,y_test,train=True)
metric_score(knn,x_train,x_test,y_train,y_test,train=False)
# Out:
# ===================Train Results============
# R2_score: 87.28620519928452 %
#
# Mean Squared Error: 0.02043421674644903
#
# Mean Absolute Error: 0.09773020481833165
#
#
# ===================Test Results============
# R2_score: 79.4906525750694 %
#
# Mean Squared Error: 0.03368072033898305
#
# Mean Absolute Error: 0.12464077212806025

# %%
#gbr

# %%
metric_score(gbr,x_train,x_test,y_train,y_test,train=True)
metric_score(gbr,x_train,x_test,y_train,y_test,train=False)
# Out:
# ===================Train Results============
# R2_score: 68.82194169193323 %
#
# Mean Squared Error: 0.05011086077656444
#
# Mean Absolute Error: 0.16753812254723677
#
#
# ===================Test Results============
# R2_score: 67.08503180665136 %
#
# Mean Squared Error: 0.05405339408016048
#
# Mean Absolute Error: 0.17271104255620423

# %%
# Random Forest gibes the best performance. so i selected Random Forest as final Model

# %%
#Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge,Lasso,RidgeCV, LassoCV

# %%
params = {'n_estimators': [13,15,17],
         'max_depth':[5,6],
         'min_samples_split':[5,6],
         'min_samples_leaf':[3,5,6]
         }

# %%
grd = GridSearchCV(rf,param_grid=params)

# %%
grd.fit(x_train,y_train)
grd.best_params_
# Out:
# {'max_depth': 6,
#  'min_samples_leaf': 6,
#  'min_samples_split': 6,
#  'n_estimators': 17}

# %%
random_tuned = grd.best_estimator_
random_tuned.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=6, min_samples_leaf=6, min_samples_split=6,
#                       n_estimators=17)

# %%
metric_score(random_tuned,x_train,x_test,y_train,y_test,train=True)
metric_score(random_tuned,x_train,x_test,y_train,y_test,train=False)
# Out:
# ===================Train Results============
# R2_score: 63.967775255646345 %
#
# Mean Squared Error: 0.05791270834742836
#
# Mean Absolute Error: 0.18003758392052233
#
#
# ===================Test Results============
# R2_score: 63.05532533315292 %
#
# Mean Squared Error: 0.06067103110049341
#
# Mean Absolute Error: 0.1842074389958404

# %%
#saving the model

# %%
filename = 'Avacado_priceprediction'
pickle.dump(random_tuned,open(filename,'wb'))

# %%
saved_mod = pickle.load(open(filename,'rb'))

# %%
prediction = saved_mod.predict(x_train)
prediction
# Out:
# array([1.46344184, 0.80940548, 1.95255387, ..., 1.70603716, 1.94211082,
#        1.75253612])

# %%
y_train
# Out:
# 17492    1.43
# 3402     0.94
# 13614    2.06
# 17607    1.43
# 14149    2.27
#          ...
# 5571     0.99
# 9063     1.05
# 10764    1.87
# 10054    2.38
# 16318    2.10
# Name: AveragePrice, Length: 12743, dtype: float64

# %%
#prediction is almost close to the actual

# %%
#MODEL FOR CLASSIFICATION MODEL ON REGION

# %%
X = data.drop(columns = ['region','Total Bags'],axis =1)
Y = data.region

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,accuracy_score, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.tree import  DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
for i in range(0,101):
    x_train,x_test,y_train,y_test = train_test_split(X_scaled,Y,train_size = 0.75,random_state = i)
    dtc.fit(x_train, y_train)
    predict_train = dtc.predict(x_train)
    predict_test = dtc.predict(x_test)
    print(f"At random state {i}, the train set accuracy is ",{accuracy_score(y_train,predict_train)})
    print(f"At random state {i}, the test set accuracy is ",{accuracy_score(y_test,predict_test)})
# Out:
# At random state 0, the train set accuracy is  {1.0}
# At random state 0, the test set accuracy is  {0.7907250470809792}
# At random state 1, the train set accuracy is  {1.0}
# At random state 1, the test set accuracy is  {0.792608286252354}
# At random state 2, the train set accuracy is  {1.0}
# At random state 2, the test set accuracy is  {0.7817796610169492}
# At random state 3, the train set accuracy is  {1.0}
# At random state 3, the test set accuracy is  {0.7862523540489642}
# At random state 4, the train set accuracy is  {1.0}
# At random state 4, the test set accuracy is  {0.7930790960451978}
# At random state 5, the train set accuracy is  {1.0}
# At random state 5, the test set accuracy is  {0.7855461393596986}
# At random state 6, the train set accuracy is  {1.0}
# At random state 6, the test set accuracy is  {0.7949623352165726}
# At random state 7, the train set accuracy is  {1.0}
# At random state 7, the test set accuracy is  {0.7893126177024482}
# ...

# %%
# at random state 70, the model perfroms well.So random state is 70

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_scaled,Y,train_size = 0.75,random_state = 70)
dtc.fit(x_train, y_train)
test_pred = dtc.predict(x_test)
print('Accuracy:', accuracy_score(y_test, test_pred)*100,'% \n')
# Out:
# Accuracy: 78.90772128060264 %

# %%
def metric_score_reg(clf,x_train,x_test,y_train,y_test,train=True):
    clf.fit(x_train, y_train)
    if train:
        train_pred = clf.predict(x_train)
        print("\n===================Train Results============")
        print('Accuracy:', accuracy_score(y_train, train_pred)*100,'% \n')
        print("\n Test Classification Report -\n", classification_report(y_train, train_pred, digits = 2))
        
    elif train == False:
        test_pred = clf.predict(x_test)
        print("\n===================Test Results============")
        print('Accuracy:', accuracy_score(y_test, test_pred)*100,'%\n')
        print("\n Test Classification Report -\n", classification_report(y_test, test_pred, digits = 2))

# %%
metric_score_reg(dtc,X_train,X_test,Y_train,Y_test, train = True)
metric_score_reg(dtc,X_train,X_test,Y_train, Y_test, train = False)
# Out:
# ===================Train Results============
# Accuracy: 100.0 %
#
#
#  Test Classification Report -
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       238
#            1       1.00      1.00      1.00       257
#            2       1.00      1.00      1.00       246
#            3       1.00      1.00      1.00       257
#            4       1.00      1.00      1.00       264
#            5       1.00      1.00      1.00       251
#            6       1.00      1.00      1.00       123
#            7       1.00      1.00      1.00       256
#            8       1.00      1.00      1.00       253
#            9       1.00      1.00      1.00       257
#           10       1.00      1.00      1.00       261
#           11       1.00      1.00      1.00       237
#           12       1.00      1.00      1.00       244
#           13       1.00      1.00      1.00       264
# ...

# %%
#Model Selection

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
rfc = RandomForestClassifier()
knnc = KNeighborsClassifier()
gbc = GradientBoostingClassifier()

# %%
#random Forest

# %%
metric_score_reg(rfc,X_train,X_test,Y_train,Y_test, train = True)
metric_score_reg(rfc,X_train,X_test,Y_train, Y_test, train = False)
# Out:
# ===================Train Results============
# Accuracy: 100.0 %
#
#
#  Test Classification Report -
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       238
#            1       1.00      1.00      1.00       257
#            2       1.00      1.00      1.00       246
#            3       1.00      1.00      1.00       257
#            4       1.00      1.00      1.00       264
#            5       1.00      1.00      1.00       251
#            6       1.00      1.00      1.00       123
#            7       1.00      1.00      1.00       256
#            8       1.00      1.00      1.00       253
#            9       1.00      1.00      1.00       257
#           10       1.00      1.00      1.00       261
#           11       1.00      1.00      1.00       237
#           12       1.00      1.00      1.00       244
#           13       1.00      1.00      1.00       264
# ...

# %%
# KNN

# %%
metric_score_reg(knnc,X_train,X_test,Y_train,Y_test, train = True)
metric_score_reg(knnc,X_train,X_test,Y_train, Y_test, train = False)
# Out:
# ===================Train Results============
# Accuracy: 74.34670014910147 %
#
#
#  Test Classification Report -
#                precision    recall  f1-score   support
#
#            0       0.58      0.83      0.68       238
#            1       0.57      0.77      0.65       257
#            2       0.73      0.89      0.80       246
#            3       0.75      0.77      0.76       257
#            4       0.69      0.81      0.75       264
#            5       0.60      0.71      0.65       251
#            6       0.93      0.92      0.93       123
#            7       0.64      0.85      0.73       256
#            8       0.91      0.93      0.92       253
#            9       0.71      0.77      0.74       257
#           10       0.54      0.66      0.59       261
#           11       0.72      0.87      0.78       237
#           12       0.82      0.78      0.80       244
#           13       0.70      0.66      0.68       264
# ...

# %%
#gradient Boosting

# %%
metric_score_reg(gbc,X_train,X_test,Y_train,Y_test, train = True)
metric_score_reg(gbc,X_train,X_test,Y_train, Y_test, train = False)
# Out:
# ===================Train Results============
# Accuracy: 98.08522325982892 %
#
#
#  Test Classification Report -
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       238
#            1       0.96      0.94      0.95       257
#            2       1.00      1.00      1.00       246
#            3       1.00      1.00      1.00       257
#            4       1.00      1.00      1.00       264
#            5       0.98      0.96      0.97       251
#            6       1.00      1.00      1.00       123
#            7       0.98      1.00      0.99       256
#            8       1.00      1.00      1.00       253
#            9       0.97      0.98      0.97       257
#           10       0.95      0.98      0.96       261
#           11       0.99      0.99      0.99       237
#           12       1.00      1.00      1.00       244
#           13       0.98      0.97      0.98       264
# ...

# %%
# Gradient Boosting classifier gives the best performance. so i selected Gradient Boosting classifier as final Model

# %%
#Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_param = {'max_depth' : range (4,8),
             'min_samples_split' : range (2,8,2),
             'learning_rate' : np.arange (0.1,0.5)}

# %%
grid = GridSearchCV(gbc, param_grid = grid_param)
grid.fit(X_train, Y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': array([0.1]),
#                          'max_depth': range(4, 8),
#                          'min_samples_split': range(2, 8, 2)})

# %%
best = grid.best_params_
best
# Out:
# {'learning_rate': 0.1, 'max_depth': 7, 'min_samples_split': 6}

# %%
final_model = GradientBoostingClassifier(learning_rate= 0.1, max_depth= 7, min_samples_split= 6)

# %%
final_model.fit(X_train, Y_train)
# Out:
# GradientBoostingClassifier(max_depth=7, min_samples_split=6)

# %%
metric_score_reg(final_model,X_train,X_test,Y_train,Y_test, train = True)
metric_score_reg(final_model,X_train,X_test,Y_train, Y_test, train = False)
# Out:
# ===================Train Results============
# Accuracy: 100.0 %
#
#
#  Test Classification Report -
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       238
#            1       1.00      1.00      1.00       257
#            2       1.00      1.00      1.00       246
#            3       1.00      1.00      1.00       257
#            4       1.00      1.00      1.00       264
#            5       1.00      1.00      1.00       251
#            6       1.00      1.00      1.00       123
#            7       1.00      1.00      1.00       256
#            8       1.00      1.00      1.00       253
#            9       1.00      1.00      1.00       257
#           10       1.00      1.00      1.00       261
#           11       1.00      1.00      1.00       237
#           12       1.00      1.00      1.00       244
#           13       1.00      1.00      1.00       264
# ...

# %%
#saving the model

# %%
filename = 'Avacado_priceprediction'
pickle.dump(random_tuned,open(filename,'wb'))
